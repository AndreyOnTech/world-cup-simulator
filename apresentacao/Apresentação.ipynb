# %%
import math

# %%
franca = 1870.70
nicaragua = 1114.63

# %% [markdown]
# Expectativa de vitória França X Nicarágua

# %%
expectativa_franca_vencer = 1 / (
    1 + math.pow(10, (nicaragua - franca) / 600)
)

print(f"{expectativa_franca_vencer:.2%}")
# Out:
# 94.79%
